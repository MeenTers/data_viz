# %% [markdown]
# <a href="https://colab.research.google.com/github/MeenTers/data_viz/blob/main/Quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/data_viz'

# %%
province_path = os.path.join(path,'3.-41-58.xls')

# %%
province_df = pd.read_excel(province_path)
province_df
# Out:
#    รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  ...          Unnamed: 12
# 0   Average Monthly Income Per Household: 1998 - 2015                        ...                  NaN
# 1                                                 NaN                        ...         บาท   Baht
# 2                                      ภาค และจังหวัด                        ...  Region and province
# 3                                                 NaN                        ...                  NaN
# 4                                                 NaN                        ...                  NaN
# ..                                                ...                        ...                  ...
# 87                                           นราธิวาส                        ...           Narathiwat
# 88                                                NaN                        ...                  NaN
# ...

# %%
a = province_df.drop([0,1,3,4,5,6,11,34,52,88,73,89,90,91])

# %%
a.drop(columns=['Unnamed: 1'])
# Out:
#    รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  ...          Unnamed: 12
# 2                                      ภาค และจังหวัด                        ...  Region and province
# 7                                       กรุงเทพมหานคร                        ...              Bangkok
# 8                                         สมุทรปราการ                        ...         Samut Prakan
# 9                                             นนทบุรี                        ...           Nonthaburi
# 10                                           ปทุมธานี                        ...         Pathum Thani
# ..                                                ...                        ...                  ...
# 83                                               ตรัง                        ...                Trang
# 84                                             พัทลุง                        ...           Phattalung
# ...
